# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os

maskpath='/home-local/ratel-ra/Bureau/ESRF_DATA/'
saxs_mask=maskpath+'mask_saxs.edf'
usaxs_mask=maskpath+'mask_usaxs.edf'
mask_LGC=maskpath+'mask_LGC.edf'
qusaxs=[0.001,0.005,0.01]
qsaxsCo12=[0.01,0.034,0.068]
qsaxsJNC=[0.1,0.173]
reflections=[[1,0,0]]

# %% [markdown]
# # Extraction des profils azimutahux:
#
# Remarque:
#
# L'utilisation du Mapping contraint à avoir des valeurs de $\beta$ comprises entre 0 et 180°. On ne peut pas avoir accès au profil azimuthal complet, bien qu'il existe (en réalité il en manque une partie, mais on peut avoir le pic centré sur $\beta=0 ou 180°$ si on arrive à extraire le profil azimuthal sour toute la plage accessible).
#
# Afin d'y remédier, les profils azimuthaux SAXS et USAXS ont été extraits avec pyFAI (integrate_radial). Les corrections apportées par la projection des data dans l'espace réciproque sont négligeables aux petits et très petits angles, ce qui rend cette approche légitime.
#
# Dans ce qui suit, seuls les profils WAXS ont été extraits après projection des données dans l'espace réciproque. La comparaison des 2 méthodes (pyFAI et mapping) dans les domaines SAXS et USAXS donne des résultats très similaires (non présentés ici)

# %% [markdown]
# ## Co12 Data WAXS

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12tol/'

# %% [markdown]
# 1. Plot and save images: the goal is to get adequate scaling.

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12tol/'
ciffile = '/home-local/ratel-ra/Bureau/ESRF_DATA/Co_P63mmc.cif'
batch=BatchAzimProfileExtraction(path=path,cif=ciffile,binning=1,instrument='ID02',threshold=0.02,reflections=reflections,file_filter='LPCNOsaxs_waxs*.h5', mapping=True)
# we set mapping to True to perform the projection of data on uniaxial reciprocal space
#batch.plot_savedata(prefix='WAXS',vmin=1,vmax=3)
#batch.plot_save_azim_profiles_vs_B(prefix='WAXS')

# %% [markdown]
# 2. Fit azimuthal profiles
#
# Test Maier Saupe distribution,

# %%
cif_file='/home-local/ratel-ra/Bureau/ESRF_DATA/Co_P63mmc.cif'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',cif=cif_file,reflections=reflections,file_filter='*_waxs*.h5',threshold=0.0001,mapping=True)
batch.fit_azimprofiles_MS(prefix='WAXS')

# %% [markdown]
# ## Co12 data SAXS

# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os

maskpath='/home-local/ratel-ra/Bureau/ESRF_DATA/'
saxs_mask=maskpath+'mask_saxs.edf'
usaxs_mask=maskpath+'mask_usaxs.edf'
mask_LGC=maskpath+'mask_LGC.edf'
qusaxs=[0.001,0.005,0.01,0.015]
qsaxsCo12=[0.01,0.034,0.068, 0.1]
qsaxsJNC=[0.1,0.173]
reflections=[[1,0,0]]
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl

# %% [markdown]
# 1. sortie des images SAXS sur fond bleu avec caving (modification du code en conséquence)

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12tol/'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',threshold=0.02,qvalues=qsaxsCo12,file_filter='LPCNOsaxs_eiger2*.h5',mask=saxs_mask)
batch.plot_savedata(prefix='SAXS',qmin=0, qmax = 0.15, vmin=-4,vmax=0,cmap='jet')

# %% [markdown]
# 2.  calculer profils I(q) vertical et horizontal sur image (caving) ouverture ±10° pour chaque champ, extraire au format .dat ou .csv
#
# La fonction modifiée inclue le caving.

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12tol/'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',threshold=0.02,qvalues=qsaxsCo12,file_filter='LPCNOsaxs_eiger2*.h5',mask=saxs_mask)
batch.save_radialprofiles(prefix='SAXS',offset=0,plot=True)

# %% [markdown]
# 3. Fit des profils azimuthaux

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12tol/'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',threshold=0.02,qvalues=qsaxsCo12,file_filter='LPCNOsaxs_eiger2*.h5',mask=saxs_mask)
batch.fit_azimprofiles_MS(plot=True,prefix='SAXS',method='pyFAI')
# Out:
# /home-local/ratel-ra/anaconda3_c/envs/py311/lib/python3.11/site-packages/pyFAI/azimuthalIntegrator.py:1670: RuntimeWarning: invalid value encountered in divide
#   intensity = sum_signal / sum_normalization
# Initial refinement parameters (I, kappa, x0, a ,b ): [4888.1584905948275, 2.0, 87.63255889459045, 0.0, 3915.4673952703524]
# Refined parameters (I, kappa, x0, a, b): [4.61432117e-03 1.35790165e+01 8.86809152e+01 9.86286981e-02
#  1.63013253e+02]
# Initial refinement parameters (I, kappa, x0, a ,b ): [1675.8875222176728, 2.0, 90.29876066088475, 0.0, 1576.5026311034185]
# Refined parameters (I, kappa, x0, a, b): [1.18490563e-14 3.92791704e+01 9.01587424e+01 2.08441418e-03
#  5.91095127e+01]
# Initial refinement parameters (I, kappa, x0, a ,b ): [82.79783508581949, 2.0, 90.29876066088475, 0.0, 73.6404119334494]
# Refined parameters (I, kappa, x0, a, b): [1.05291277e-14 3.62916352e+01 9.01743393e+01 1.32279100e-03
#  2.66846156e+00]
# ...

# %% [markdown]
# 4. Ajouter un cerlce à q=0.068 sur les maps des images SAXS

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12tol/'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',threshold=0.02,qvalues=qsaxsCo12,file_filter='LPCNOsaxs_eiger2*.h5',mask=saxs_mask)
batch.plot_savedata(prefix='SAXS',vmin=-4,vmax=0,qmax=0.15,qcircles=[0.068])

# %%
batch.plot_save_azim_profiles_vs_B(method='pyFAI',prefix='SAXS')

# %% [markdown]
# # Echantillon Organométallique JNC21/JNC108

# %% [markdown]
# ## JNC 21 data SAXS
#
# Remplacé par JNC108 data SAXS (manip non viable car nanobâtonnets déjà alignés)

# %% [markdown]
# ## JNC 21 data WAXS

# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os

maskpath='/home-local/ratel-ra/Bureau/ESRF_DATA/'
saxs_mask=maskpath+'mask_saxs.edf'
usaxs_mask=maskpath+'mask_usaxs.edf'
mask_LGC=maskpath+'mask_LGC.edf'
qusaxs=[0.001,0.005,0.01,0.015]
qsaxsCo12=[0.01,0.034,0.068, 0.1]
qsaxsJNC=[0.1,0.173]
reflections=[[1,0,0]]

# %% [markdown]
# 1. Extraction des images brutes sur fond bleu

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/JNC21/'

cif_file='/home-local/ratel-ra/Bureau/ESRF_DATA/Co_P63mmc.cif'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',cif=cif_file,reflections=reflections,file_filter='*_waxs*.h5',threshold=0.0001,mapping=True)
#batch.plot_save_azim_profiles_vs_B(prefix='WAXS')
batch.fit_azimprofiles(plot=True,r2_threshold=0.75,prefix='WAXS')
#batch.plot_savedata(prefix='WAXS',vmin=1,vmax=3)

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/JNC21/'

cif_file='/home-local/ratel-ra/Bureau/ESRF_DATA/Co_P63mmc.cif'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',cif=cif_file,reflections=reflections,file_filter='*_waxs*.h5',threshold=0.0001,mapping=True)
batch.plot_savedata(prefix='WAXS',vmin=1,vmax=1.7)

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/JNC21/last_waxs/'

cif_file='/home-local/ratel-ra/Bureau/ESRF_DATA/Co_P63mmc.cif'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',cif=cif_file,reflections=reflections,file_filter='*_waxs*.h5',threshold=0.0001,mapping=True)
batch.plot_savedata(prefix='WAXS',vmin=1,vmax=2.7)

# %% [markdown]
# # Echantillon JNC108 moitié lavé _ Data SAXS LGC - pyFAI
#
# code à exécture avec les fichiers edf correspondant aux images uniques

# %% [markdown]
# 1. Sauvegarde des images sur fond bleu

# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os

maskpath='/home-local/ratel-ra/Bureau/ESRF_DATA/'
saxs_mask=maskpath+'mask_saxs.edf'
usaxs_mask=maskpath+'mask_usaxs.edf'
mask_LGC=maskpath+'mask_LGC.edf'
qusaxs=[0.001,0.005,0.01,0.015]
qsaxsCo12=[0.01,0.034,0.068, 0.1]
qsaxsJNC=[0.1,0.173]
reflections=[[1,0,0]]

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/etude_en_champ/'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*vd*.edf',mask=mask_LGC,skipcalib=True,mapping=False)
#batch.plot_save_azim_profiles_vs_B(prefix='SAXS_pyFAI',method='pyFAI')
#batch.fit_azimprofiles(plot=True,r2_threshold=0.5,prefix='SAXS_pyFAI', method='pyFAI')
batch.plot_savedata(prefix='SAXS', vmin=-3, vmax=0,qmax=0.15)

# %% [markdown]
# 2. Extraction des profiles horizontaux et verticaux

# %% [markdown]
# REPRENDRE ICI (J'ai déjà copié les anciens résultats)

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*.edf',mask=mask_LGC,mapping=False)
batch.save_radialprofiles(prefix='SAXS',offset=-90, width=10)# this method is based on pyFAI

# %% [markdown]
# 3.Etude en fonction du champ.
#
# Pour chaque valeur de champ, on prend le dernier point réalisé à ce champ
#
# - Extraction des profils horizontaux et verticaux (batch.save_radialprofiles)
# - Calcul de S (batch.fit_azimprofiles)

# %%
path = '/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/etude_en_champ/'

batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*vd*.edf',mask=mask_LGC)
batch.save_radialprofiles(prefix='SAXS',offset=-90)

# %%
batch.plot_save_azim_profiles_vs_B(prefix='SAXS',method='pyFAI')

# %%
path = '/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/etude_en_champ/'

batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*vd*.edf',mask=mask_LGC)
batch.fit_azimprofiles(beta_target=0,plot=True,r2_threshold=0.9,prefix='SAXS', method='pyFAI')

# %%
batch.fit_azimprofiles(beta_target=-90,plot=True,r2_threshold=0.2,prefix='SAXS', method='pyFAI')

# %% [markdown]
# 4. Etude cinétique à champ constant
#
# - Extraction des profils horizontaux et verticaux (batch.save_radialprofiles)
# - Calcul de S (batch.fit_azimprofiles)

# %% [markdown]
# ### B= 600mT

# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os

maskpath='/home-local/ratel-ra/Bureau/ESRF_DATA/'
saxs_mask=maskpath+'mask_saxs.edf'
usaxs_mask=maskpath+'mask_usaxs.edf'
mask_LGC=maskpath+'mask_LGC.edf'
qusaxs=[0.001,0.005,0.01,0.015]
qsaxsCo12=[0.01,0.034,0.068, 0.1]
qsaxsJNC=[0.1,0.173]
reflections=[[1,0,0]]

path = '/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/etude_cinetique_600mT/'

batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*vd*.edf',mask=mask_LGC,mapping=False)
batch.plot_savedata(prefix='SAXS', vmin=-3, qmax=0.15,kinetic=True)
#batch.plot_save_azim_profiles_vs_time(prefix='SAXS',method='pyFAI')
#batch.save_radialprofiles(prefix='SAXS',offset=-90,kinetic=True)

# %%
batch.build_timearray()
print(batch.epoch)

# %%
path = '/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/etude_cinetique_600mT/'

batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*vd*.edf',mask=mask_LGC,mapping=False)
batch.fit_azimprofiles_vs_time(beta_target=0,plot=True,r2_threshold=0.99,prefix='SAXS',method='pyFAI') # Compute S and stores in csv

# %% [markdown]
# Comme on a coexistence de 2 états, je calcule le paramètre nématique pour les 2 orientations... Ci dessus on a fait l'orientation principale (horizontale).
# Ci dessous je calcule pour l'orientation verticale (batonnets horizontaux). Ce calcul est rendu possible en spcéifiant beta_target dans les arguments du la méthode fit_azimprofiles()

# %%
path = '/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/etude_cinetique_600mT/'

batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*vd*.edf',mask=mask_LGC,mapping=False)
batch.fit_azimprofiles_vs_time(beta_target=-90,plot=True,r2_threshold=0.6,prefix='SAXS',method='pyFAI') # Compute S and stores in csv

# %% [markdown]
# ### B= 700mT

# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os

maskpath='/home-local/ratel-ra/Bureau/ESRF_DATA/'
saxs_mask=maskpath+'mask_saxs.edf'
usaxs_mask=maskpath+'mask_usaxs.edf'
mask_LGC=maskpath+'mask_LGC.edf'
qusaxs=[0.001,0.005,0.01,0.015]
qsaxsCo12=[0.01,0.034,0.068, 0.1]
qsaxsJNC=[0.1,0.173]
reflections=[[1,0,0]]

path = '/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/etude_cinetique_700mT/'

batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*vd*.edf',mask=mask_LGC,mapping=False)
batch.plot_savedata(prefix='SAXS', vmin=-3, vmax=0,qmax=0.15,kinetic=True)
#batch.plot_save_azim_profiles_vs_time(prefix='SAXS',method='pyFAI')
#batch.save_radialprofiles(prefix='SAXS',offset=-90,kinetic=True)

# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os

maskpath='/home-local/ratel-ra/Bureau/ESRF_DATA/'
saxs_mask=maskpath+'mask_saxs.edf'
usaxs_mask=maskpath+'mask_usaxs.edf'
mask_LGC=maskpath+'mask_LGC.edf'
qusaxs=[0.001,0.005,0.01,0.015]
qsaxsCo12=[0.01,0.034,0.068, 0.1]
qsaxsJNC=[0.1,0.173]
reflections=[[1,0,0]]
path = '/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108moitielave_LGC/etude_cinetique_700mT/'

batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=qsaxsJNC,file_filter='*vd*.edf',mask=mask_LGC,mapping=False)
batch.fit_azimprofiles_vs_time(beta_target=0,plot=True,r2_threshold=0.917,prefix='SAXS',method='pyFAI') # Compute S and stores in csv

# %%
batch.fit_azimprofiles_vs_time(beta_target=-90,plot=True,r2_threshold=0.99,prefix='SAXS',method='pyFAI') # Compute S and stores in csv
