# %%
# %matplotlib widget
from utilities_SWING import compute_global_nematic_parameter
from utilities_SWING import compute_nematic_order_assembly_SWING
from utilities_SWING import view_position_grid
from saxsprocessor import SAXSProcessor
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl

# %% [markdown]
# **Plot average image**

# %%
file = '/home-local/ratel-ra/Documents/SAXS_data/SAXS_SWING/test_SAXSProcessor/lacroix_00592_2024-07-20_00-07-24.h5'
mask = '/home-local/ratel-ra/Documents/SAXS_data/SAXS_SWING/test_SAXSProcessor/mask.edf'
proc = SAXSProcessor(file = file, mask=mask,instrument='SWING')
proc.plot2d_vsq(q_range=[0,0.15])
# Out:
# No motor positions provided. Update filereaders.py if required
# Initial pixel size: 7.5e-05x7.5e-05
# Due to binning, pixel size was modified to 0.00015x0.00015
# ✅ SAXS image saved: /home-local/ratel-ra/Documents/SAXS_data/SAXS_SWING/test_SAXSProcessor/saxs_images/co21_12_Img_592.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Paramètre nématique global**

# %%
h5path = '/home-local/ratel-ra/Documents/SAXS_data/SAXS_SWING/test_SAXSProcessor/'
mask = h5path +'mask.edf'
S = compute_global_nematic_parameter(h5path=h5path, mask = mask)

# %% [markdown]
# **View grid positions**

# %%
h5path = '/home-local/ratel-ra/Documents/SAXS_data/SAXS_SWING/test_SAXSProcessor/'
mask = h5path +'mask.edf'
view_position_grid(h5path=h5path)

# %% [markdown]
# **Compute nematic order paramter map**

# %%
#compute_nematic_order_assembly_SWING(h5path=h5path, mask=mask)
